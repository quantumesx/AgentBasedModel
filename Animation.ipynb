# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

s
# initialization function: plot the background of each frame
def init():
    line.set_data([], [])
    return line,

# animation function.  This is called sequentially
def animate(i):
    x = np.linspace(0, 2, 1000)
    y = np.sin(2 * np.pi * (x - 0.01 * i))
    line.set_data(x, y)
    return line,

# call the animator.  blit=True means only re-draw the parts that have changed.
anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=200, interval=20, blit=True)

# save the animation as an mp4.  This requires ffmpeg or mencoder to be
# installed.  The extra_args ensure that the x264 codec is used, so that
# the video can be embedded in html5.  You may need to adjust this for
# your system: for more information, see
# http://matplotlib.sourceforge.net/api/animation_api.html
anim.save('basic_animation.mp4', fps=30, extra_args=['-vcodec', 'libx264'])

plt.show()

# %%
# Environment

# arena
height = 270
width = 270

# target areas
target1 = (80, 80)
target2 = (190, 190)
target_r = 45

# %%
# Agents
agent = (30, 40)
agent_r = 11

# %%
# Sensors and Motors
sensor1 = agent # sensor1 coordinates
sensor2 = agent # sensor2 coordinates

motor1 = agent # motor1 coordinates
motor2 = agent # motor2 coordinates

# do I want this still?
head_ang = 0

# IR sensors
IR_ang = [] # angs for 8 sensors


# ground sensor
ground = 0

# comm. sensor - other
comm_in = [0, 90, 180, 270]
comm_in_range = 90

# comm. sensor - self
comm_out = 0

# motors
motor_ang = [-90, 90]

# comm. node
comm_out = 0

# %%
# Neuron Network

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

# %%
fig = plt.figure()
ax = plt.axes(xlim=(0, width), ylim=(0, height))

line, = ax.plot([], [])

circ1 = Circle(target1, target_r)
ax.add_patch(circ1)
circ2 = Circle(target2, target_r)
ax.add_patch(circ2)

circ3 = Circle(agent, agent_r, color='c')
ax.add_patch(circ3)

ax.set_aspect('equal')

# %%
# environment to IR sensor
# - check for each sensor:
# - if there is anything in the range
# - the closest one that is not "empty" would determine the sensor reading
# 

# environment to ground sensor
# - check if is in the target area
# - the closest one that is not "empty" would determine the sensor reading
# 


# sensor to input
# - scale the sensor to 0-1
# -
# input to output
# - neural network
# -
# output to motor
# - 
# - 
# motor to movement
# - start simple now
# - 

agent
- sensors
- motors
- controller

environment
- floor color
- presence of obstacle (either agent or wall)
- presence of agent

IR sensor attributes
- current reading
- input to network
- detectable range
- stored reading

ground sensor attributes
- current reading
- input to network
- stored reading

Comm. sensor attributes
- current reading
- input to network
- detectable range
- stored reading

Comm. sensor 
- 
-
-
-

wheel attributes
-
-
-
-

Comm. motor
-
-
-
-
# Out:
# array([ 285.430276  ,  192.63974878,  485.81922316,  361.24724056,
#          26.82132661])

# %%
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.patches import Circle

# Get an example image
import matplotlib.cbook as cbook
image_file = cbook.get_sample_data('grace_hopper.png')
img = plt.imread(image_file)

# Make some example data
x = np.random.rand(5)*img.shape[1]
y = np.random.rand(5)*img.shape[0]

# Create a figure. Equal aspect so circles look circular
fig,ax = plt.subplots(1)
ax.set_aspect('equal')

# Show the image
ax.imshow(img)

# Now, loop through coord arrays, and create a circle at each x,y pair
for xx,yy in zip(x,y):
    circ = Circle((xx,yy),50)
    ax.add_patch(circ)

# Show the image
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation

nx = 20
ny = 20

fig = plt.figure()
plt.axis([0,nx,0,ny])
ax = plt.gca()
ax.set_aspect(1)

def init():
    # initialize an empty list of cirlces
    return []

def animate(i):
    # draw circles, select to color for the circles based on the input argument i. 
    patches = [
        Circle(self.loc, self.r, color='green')
        
    ]
    # body
    ax.add_patch(Circle(self.loc, self.r, color='green')) # target[0] = target_loc (x, y) , target[1] = target_r
    ax.add_patch(FancyArrow(self.loc[0], self.loc[1], 
                                find_dx(self.loc[0], self.ang, 4.5), find_dy(self.loc[1], self.ang, 10),
                                color='black', length_includes_head=False, head_width=1))

    
    
    
    someColors = ['r', 'b', 'g', 'm', 'y']
    patches = []
    for x in range(0,nx):
        for y in range(0,ny):
            patches.append(ax.add_patch(Circle((x+0.5,y+0.5),0.45,color=someColors[i % 5]) ))
    return patches

anim = animation.FuncAnimation(fig, animate, init_func=init,
                               frames=100, interval=20, blit=True)
plt.show()

# %%
import numpy as np
from matplotlib import pyplot as plt
from matplotlib import animation


fig = plt.figure()
fig.set_dpi(100)
fig.set_size_inches(7, 6.5)

ax = plt.axes(xlim=(0, 10), ylim=(0, 10))

patch = plt.Circle((5, -5), 0.75, fc='y')

def init():
    patch.center = (5, 5)
    ax.add_patch(patch)
    return patch,

def animate(i):
    x, y = patch.center
    x = 5 + 3 * np.sin(np.radians(i))
    y = 5 + 3 * np.cos(np.radians(i))
    patch.center = (x, y)
    return patch,

anim = animation.FuncAnimation(fig, animate, 
                               init_func=init, 
                               frames=360, 
                               interval=20,
                               blit=True)

plt.show()
anim.save('patch.mp4', fps=100, extra_args=['-vcodec', 'libx264'])
